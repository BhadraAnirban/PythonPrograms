# %%
# Open the file in read ('r') mode
file = open('filehelper.txt', 'r')
file_stuff = file.read()
print(file_stuff);
file.close()
print('File closed successfully')
# Out:
# â€¦or create a new repository on the command line
# echo "# PythonPrograms" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git push -u origin main
#
#
#
# â€¦or push an existing repository from the command line
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git branch -M main
# git push -u origin main
# File closed successfully

# %%
with open('filehelper.txt', 'r') as file:
    for n in range(0, 2):
        print(n, ": ", file.readline())
# Out:
# 0 :
#
# 1 :  â€¦or create a new repository on the command line

# %%
# Reading and Storing the Entire Content of a File

# Using the read method, you can retrieve the complete content of a file
# and store it as a string in a variable for further processing or display.

# Step 1: Open the file you want to read
with open('filehelper.txt', 'r') as file:

    # Step 2: Use the read method to read the entire content of the file
    file_stuff = file.read()

    # Step 3: Now that the file content is stored in the variable 'file_stuff',
    # you can manipulate or display it as needed.

    # For example, let's print the content to the console:
    print(file_stuff)

# Step 4: The 'with' statement automatically closes the file when it's done,
# ensuring proper resource management and preventing resource leaks.
# Out:
# â€¦or create a new repository on the command line
# echo "# PythonPrograms" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git push -u origin main
#
#
#
# â€¦or push an existing repository from the command line
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git branch -M main
# git push -u origin main

# %%
with open('filehelper.txt', 'r') as fileHelper:
    file_content = fileHelper.read()
    print('Read successful')

print(file_content)
print('Reading again')
file_content2 = fileHelper.read()
# Out:
# Read successful
#
# â€¦or create a new repository on the command line
# echo "# PythonPrograms" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git push -u origin main
#
#
#
# â€¦or push an existing repository from the command line
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git branch -M main
# git push -u origin main
# Reading again
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       3     print('Read successful')
#       4
#       5 print(file_content)
#       6 print('Reading again')
# ----> 7 file_content2 = fileHelper.read()
#
# ValueError: I/O operation on closed file.

# %%
with open('filehelper.txt', 'r') as fileHelper:

    line1 = fileHelper.readline()  # Reads the first line
    print('line1: ', line1)
    line2 = fileHelper.readline()  # Reads the second line
    print('line2: ',line2)
    line3 = fileHelper.readline()  # Reads the second line
    print('line3: ',line3)
    print('line4: ',fileHelper.readline())
    print('line5: ',fileHelper.readline())

    print('read lines: ', fileHelper.readlines())
# Out:
# line1:
#
# line2:  â€¦or create a new repository on the command line
#
# line3:  echo "# PythonPrograms" >> README.md
#
# line4:  git init
#
# line5:  git add README.md
#
# read lines:  ['git commit -m "first commit"\n', 'git branch -M main\n', 'git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git\n', 'git push -u origin main\n', '\n', '\n', '\n', 'â€¦or push an existing repository from the command line\n', 'git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git\n', 'git branch -M main\n', 'git push -u origin main']

# %%
with open('filehelper.txt', 'r') as file:
    count = 0
    while True:
        line = file.readline()
        count = count + 1
        if not line:
            break  # Stop when there are no more lines to read
        elif 'git' not in line and line.strip():
            print('Line ', count, 'is: ',line)
print('Read Ends Here')
# Out:
# Line  2 is:  â€¦or create a new repository on the command line
#
# Line  3 is:  echo "# PythonPrograms" >> README.md
#
# Line  13 is:  â€¦or push an existing repository from the command line
#
# Read Ends Here

# %%
with open('filehelper.txt', 'r') as readFile:
    with open('filehelperCopy.txt', 'w') as writeFile:
        for line in readFile:
            if line.strip():
                writeFile.write(line)
print('Copy Completed');
# Out:
# Copy Completed

# %%
with open('filehelperCopy.txt', 'r') as writeFile:
    print(writeFile.read())
# Out:
# â€¦or create a new repository on the command line
# echo "# PythonPrograms" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git push -u origin main
# â€¦or push an existing repository from the command line
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git branch -M main
# git push -u origin main

# %%
import os
fileName = input('Enter File name here: ');
if os.path.exists(fileName):   
    with open(fileName, 'r') as myfile:         
        print(myfile.read())
        print(f'Content of {myfile.name} is displayed')
else:
    print('Filename Does not present')
# Out:
# Enter File name here:  filehelper.txt
# â€¦or create a new repository on the command line
# echo "# PythonPrograms" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git push -u origin main
#
#
#
# â€¦or push an existing repository from the command line
# git remote add origin https://github.com/BhadraAnirban/PythonPrograms.git
# git branch -M main
# git push -u origin main
# Content of filehelper.txt is displayed

# %%
for n in range(0, 2):

    print(myfile.readline())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 for n in range(0, 2):
#       2
# ----> 3     print(myfile.readline())
#
# NameError: name 'myfile' is not defined
