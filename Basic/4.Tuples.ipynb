# %% [markdown]
# ### Tuples are in ordered sequence written in comma seperated with in paranthess ()
# #### Tuples are immutable. Means we can not do => touple_var[2] = 2.26

# %%
tuple_var = ('pmkj', 2, 26.2)

# %%
print(tuple_var[0])
print(tuple_var[1])
print(tuple_var[2])
# Out:
# pmkj
# 2
# 26.2

# %%
print(len(tuple_var))
# Out:
# 3

# %% [markdown]
# ### Touple Concatenation

# %%
new_tuple = tuple_var + ('BBM', 2)

# %%
print(len(new_tuple))
# Out:
# 5

# %%
print(new_tuple)
# Out:
# ('pmkj', 2, 26.2, 'BBM', 2)

# %% [markdown]
# ### Touple Slicing

# %%
print(new_tuple[0: 4])
print(new_tuple[2: 4])
# Out:
# ('pmkj', 2, 26.2, 'BBM')
# (26.2, 'BBM')

# %%
new_tuple[2] = 2.26
print(new_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 new_tuple[2] = 2.26
#       2 print(new_tuple)
#
# TypeError: 'tuple' object does not support item assignment
