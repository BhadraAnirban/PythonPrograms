# %% [markdown]
# ## The first code for my python universe

# %%
pmkj = 2
bbm = 10

# %%
print("pmkj: ", pmkj); print("BBM: ", bbm)
# Out:
# pmkj:  2
# BBM:  10

# %%
print("Universe: ", pmkj + bbm)
# Out:
# Universe:  12
