# %% [markdown]
# #### Set does not record the element position. Set can have unique element

# %%
my_set = {12, 25,11, 44}
my_set
# Out:
# {11, 12, 25, 44}

# %%
# Convert list to set

album_list = [ "Michael Jackson", "Thriller", 1982, "00:42:19", \
              "Pop, Rock, R&B", 46.0, 65, "30-Nov-82", None, 10.0]
album_set = set(album_list)             
album_set
# Out:
# {'00:42:19',
#  10.0,
#  1982,
#  '30-Nov-82',
#  46.0,
#  65,
#  'Michael Jackson',
#  None,
#  'Pop, Rock, R&B',
#  'Thriller'}

# %%
my_set.add("NSYNC")
my_set
# Out:
# {11, 12, 25, 44, 'NSYNC'}

# %%
my_set.remove(44)
my_set
# Out:
# {11, 12, 25, 'NSYNC'}

# %%
25 in my_set
# Out:
# True

# %%
# Sample Sets

album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])

# %%
# Print two sets

album_set1, album_set2
# Out:
# ({'AC/DC', 'Back in Black', 'Thriller'},
#  {'AC/DC', 'Back in Black', 'The Dark Side of the Moon'})

# %%
# Find the intersections

intersection = album_set1 & album_set2
intersection
# Out:
# {'AC/DC', 'Back in Black'}

# %%
# Find the difference in set1 but not set2

album_set1.difference(album_set2)
# Out:
# {'Thriller'}

# %%
album_set2.difference(album_set1)
# Out:
# {'The Dark Side of the Moon'}

# %%
album_set1.intersection(album_set2)
# Out:
# {'AC/DC', 'Back in Black'}

# %%
album_set1.union(album_set2)
# Out:
# {'AC/DC', 'Back in Black', 'The Dark Side of the Moon', 'Thriller'}

# %%
# Check if superset

set(album_set1).issuperset(album_set2)
# Out:
# False

# %%
# Check if subset

set(album_set2).issubset(album_set1)
# Out:
# False

# %%
# Check if subset

set({"Back in Black", "AC/DC"}).issubset(album_set1)
# Out:
# True

# %%
album_set3 = album_set1.difference(album_set2)  
album_set3
# Out:
# {'Thriller'}

# %%
album_set3.issubset(album_set1)
# Out:
# True

# %%
album_set1.issubset(album_set3)
# Out:
# False

# %%
album_set1.issuperset(album_set3)
# Out:
# True

# %%
album_set3.issuperset(album_set1)
# Out:
# False

# %%
A = [1, 2, 2, 1]
B = set([1, 2, 2, 1])
sum(A) == sum(B)
# Out:
# False

# %%
album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])
album_set3 = album_set1.union(album_set2)
album_set3
# Out:
# {'AC/DC', 'Back in Black', 'The Dark Side of the Moon', 'Thriller'}

# %%
nav_menu = ["Home", "Products", "About Us", "Contact"]
del(nav_menu[1])
nav_menu
# Out:
# ['Home', 'About Us', 'Contact']

# %%
demographics = ("Female", 35, "PhD", "Engineering", "Urban")

# %%
len(demographics)
# Out:
# 5

# %%
count(demographics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 count(demographics)
#
# NameError: name 'count' is not defined
