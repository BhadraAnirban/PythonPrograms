# %%
def f1(input):
    """
    add 1 to the input
    """
    return input + 1;

# %%
help(f1)
# Out:
# Help on function f1 in module __main__:
#
# f1(input)
#     add 1 to the input

# %%
print(f1(25))
print(f1(1))
# Out:
# 26
# 2

# %%
rating = [4, 2, 7, 6, 1]
new_rating = sorted(rating) #sorted() function sort the list to a new list
print('rating',rating)
print('new_rating', new_rating)
rating.sort() #sort() function sort the list itself
print('rating',rating)
# Out:
# rating [4, 2, 7, 6, 1]
# new_rating [1, 2, 4, 6, 7]
# rating [1, 2, 4, 6, 7]

# %%
def fun1(a, b):
    print(a + b)
    return None

# %%
fun1(2, 26)
# Out:
# 28

# %%
def argumentsFun(*data):
    for item in data:
        print(item)

# %%
argumentsFun('a', 'b', 'c')
# Out:
# a
# b
# c

# %%
argumentsFun(2, 26)
# Out:
# 2
# 26

# %%
 len([sum([1,1,1])])
# Out:
# 1

# %%
len([1])
# Out:
# 1
