# %%
string_variable = 'Pranabananda'

# %%
len(string_variable)
# Out:
# 12

# %%
3*string_variable
# Out:
# 'PranabanandaPranabanandaPranabananda'

# %% [markdown]
# ## String Methods-

# %%
#upper method-
print(string_variable.upper())
# Out:
# PRANABANANDA

# %%
string_variable = string_variable + ' maharaj'

# %%
print(string_variable)
# Out:
# Pranabananda maharaj

# %%
#replace method-
string_variable = string_variable.replace('maharaj', 'maharaj ki jay')

# %%
print(string_variable)
# Out:
# Pranabananda maharaj ki jay ki jay ki jay

# %%
#find method-

# %%
print(string_variable.find('ki'))
# Out:
# 21

# %%
#if not found the output is -1
print(string_variable.find('aja'))
# Out:
# -1

# %% [markdown]
# ## String interpolation (f-strings)

# %% [markdown]
# ### f-strings are a new way to format strings in Python. They are prefixed with 'f' and use curly braces {} to enclose the variables that will be formatted.

# %%
name = "BBM"
age = 6
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is BBM and I am 6 years old.

# %%
print(f"How are you {name}!")
# Out:
# How are you BBM!

# %% [markdown]
# ## str.format()

# %%
srtng_var = "Welcome {} with age {}"
print(srtng_var.format(name, age))
# Out:
# Welcome BBM with age 6

# %%
print(string_variable)
print(string_variable[0])
print(string_variable[-1])
print(string_variable[-2])
# Out:
# Pranabananda maharaj ki jay ki jay ki jay
# P
# y
# a

# %% [markdown]
# #### Addition (+): Adds two values together.- Subtraction (-): Subtracts one value from another.- Multiplication (*): Multiplies two values.- Division (/): Divides one value by another, returns a float.- Floor Division (//): Divides one value by another, returns the quotient as an integer.- Modulo (%): Returns the remainder after division.

# %% [markdown]
# ### Slicing  string_name[start:end]

# %%
substring = string_variable[2:10]  
print(substring)
# Out:
# anabanan

# %% [markdown]
# ### split() Splits string into a list based on a delimiter.

# %%
print(string_variable.split(' '))
# Out:
# ['Pranabananda', 'maharaj', 'ki', 'jay', 'ki', 'jay', 'ki', 'jay']

# %% [markdown]
# ### strip() Removes leading/trailing whitespace.
#
# #### Example: my_string="Hello"; trimmed = my_string.strip()

# %%
new_ver = 'data science basics'
print(new_ver.title())
print(new_ver.capitalize())
# Out:
# Data Science Basics
# Data science basics

# %%
nmew_veria = 'ABC-12345-XYZ'
print(nmew_veria[4:8])
print(nmew_veria[4:9])
# Out:
# 1234
# 12345
