# %%
a = True #T or F should be upper case for boolean
b = 26
c = 2.26
d = "string data type 26"

# %%
print(a," --> ", type(a))
print(b," --> ", type(b) )
print(c," --> ", type(c) )
print(d," --> ", type(d) );
# Out:
# True  -->  <class 'bool'>
# 26  -->  <class 'int'>
# 2.26  -->  <class 'float'>
# string data type 26  -->  <class 'str'>

# %% [markdown]
# ### Change Expression Type

# %%
print(int(a))
print(float(b))
print(int(c))
print(str(c))
print(int("2"))
print(bool(1))
# Out:
# 1
# 26.0
# 2
# 2.26
# 2
# True
