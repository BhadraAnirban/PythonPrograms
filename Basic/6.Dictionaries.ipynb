# %%
dist = {'key1': 2, 'key2': 'bbm', 'key3': ['pmkj', 26]}

# %%
print(dist)
# Out:
# {'key1': 2, 'key2': 'bbm', 'key3': ['pmkj', 26]}

# %%
len(dist)
# Out:
# 3

# %%
dist.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
print(dist.keys())
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %% [markdown]
# #### Note the difference between dist.keys() and list(dist.keys())

# %%
list(dist.keys())
# Out:
# ['key1', 'key2', 'key3']

# %%
dist.values()
# Out:
# dict_values([2, 'bbm', ['pmkj', 26]])

# %%
dist['key3']
# Out:
# ['pmkj', 26]

# %%
'key3' in dist
# Out:
# True

# %%
del(dist['key3'])
print(dist)
# Out:
# {'key1': 2, 'key2': 'bbm'}

# %%
dist['key4'] = 26
print(dist)
# Out:
# {'key1': 2, 'key2': 'bbm', 'key4': 26}

# %%
new_dist = {"a":1,"b":2}
new_dist.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
list(new_dist.keys())
# Out:
# ['a', 'b']
