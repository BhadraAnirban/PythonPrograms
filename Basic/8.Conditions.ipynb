# %%
age = 12

# %%
print('check')
if age > 20:
    print("yes")
print('complete')
# Out:
# check
# complete

# %%
print('2nd check')
if age > 26:
    print("yes")
else:
    print('no')
print('complete')
# Out:
# 2nd check
# no
# complete

# %%
if age > 20:
    print('greater than 20')
else: if age > 15:
    print('greater than 15')
print('greater')
# Out:
#   Cell In[4], line 3
#     else: if age > 15:
#           ^
# SyntaxError: invalid syntax

# %%
if age > 20:
    print('greater than 20')
else: 
    if age > 15:
        print('greater than 15')
print('complete')
# Out:
# complete

# %%
age = 19
if age > 20:
    print('greater than 20')
elif(age > 15) or:
    print('greater than 15')
elif(age > 10):
    print('greater than 10')
else:
    print('less than 10')

print('complete')
# Out:
#   Cell In[6], line 4
#     elif(age > 15) or:
#                      ^
# SyntaxError: invalid syntax

# %%
my_num = 15

if(my_num == 15) or (my_num < 15):
    print('number is less than 16')
else:
    print('number is greater than 15')
# Out:
# number is less than 16

# %%
action = 'learn'
amount = 0
if action == 'learn':
    amount = int(input('Your Budget: '))
else:
    print('try again')
print(f'your budget is: {amount}')
# Out:
# Your Budget:  26
# your budget is: 26

# %%
'a' == 'A'
# Out:
# False

# %%
1 = 2
# Out:
#   Cell In[18], line 1
#     1 = 2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
current_temp = 18
current_temp = current_temp > 25
print(current_temp)
# Out:
# False

# %%
def add(a, b): 
    return(sum((a, b)))
print(add(2,3));
# Out:
# 5
